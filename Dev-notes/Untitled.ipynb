# %%
# !{sys.executable} -m pip install -e /Users/phantom/Quant/Anake/ananke-sdk/
# Out:
# zsh:1: parse error near `-m'

# %%
from ananke import Kairos
from ananke.indicators import rsi, sma, ema, macd, bollinger, atr, vwap
from ananke.trade import Trade  !{sys.executable} -m pip install -e /Users/phantom/Quant/Anake/ananke-sdk/
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ananke import Kairos
#       2 from ananke.indicators import rsi, sma, ema, macd, bollinger, atr, vwap
#       3 from ananke.trade import Trade
#
# ModuleNotFoundError: No module named 'ananke'
