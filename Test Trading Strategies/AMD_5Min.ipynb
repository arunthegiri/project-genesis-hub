# %% [markdown]
# # AMD_5Min
#
# Generated from the Ananke chart view (Export to Jupyter).

# %%
# Generated by Ananke
# symbol=AMD  interval=5Min
# range: 2026-07-27T00:00:00Z -> 2026-08-04T00:00:00Z
from ananke import get_data

df = get_data("AMD", "2026-07-27T00:00:00Z", "2026-08-04T00:00:00Z", "5min")
df.head()
