# %% [markdown]
# # MSFT_1Min
#
# Generated from the Ananke chart view (Export to Jupyter).

# %%
# Generated by Ananke
# symbol=MSFT  interval=1Min
# range: 2026-07-31T00:00:00Z -> 2026-08-05T00:00:00Z
from ananke import get_data

df = get_data("MSFT", "2026-07-31T00:00:00Z", "2026-08-05T00:00:00Z", "1min")
df.head()
