# %% [markdown]
# # SNAP_5Min
#
# Generated from the Ananke chart view (Export to Jupyter).

# %%
# Generated by Ananke
# symbol=SNAP  interval=5Min
# range: 2026-07-30T00:00:00Z -> 2026-08-04T00:00:00Z
from ananke import get_data

df = get_data("SNAP", "2026-07-30T00:00:00Z", "2026-08-04T00:00:00Z", "5min")
df.head()
# Out:
# SNAP: checking coverage:   0%|          | 0/100 [00:00<?, ?%/s]
#                             open   high    low  close  volume
# time
# 2026-07-30 13:30:00+00:00  4.630  4.670  4.630  4.650   25033
# 2026-07-30 13:35:00+00:00  4.660  4.660  4.620  4.630   40043
# 2026-07-30 13:40:00+00:00  4.620  4.650  4.615  4.650   23902
# 2026-07-30 13:45:00+00:00  4.650  4.660  4.650  4.660   31080
# 2026-07-30 13:50:00+00:00  4.665  4.695  4.660  4.675   54057
