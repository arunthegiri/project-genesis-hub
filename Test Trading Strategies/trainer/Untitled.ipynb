# %%
# Generated by Ananke
# symbol=NVDA  interval=1Min
# range: 2026-07-08T00:00:00Z -> 2026-07-13T00:00:00Z
from ananke import get_data

df = get_data("NVDA", "2026-07-08T00:00:00Z", "2026-07-13T00:00:00Z", "1min")
df.head()
# Out:
# NVDA: checking coverage:   0%|          | 0/100 [00:00<?, ?%/s]
#                              open    high     low   close  volume
# time
# 2026-07-08 12:21:00+00:00  194.97  194.97  194.97  194.97     100
# 2026-07-08 12:26:00+00:00  194.73  194.73  194.72  194.72     300
# 2026-07-08 12:48:00+00:00  195.12  195.12  195.12  195.12     100
# 2026-07-08 12:50:00+00:00  195.09  195.09  195.09  195.09     100
# 2026-07-08 13:26:00+00:00  195.00  195.00  195.00  195.00     974
